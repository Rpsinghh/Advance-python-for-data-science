# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# using of style
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Scatter Plots

# %%
x=np.linspace(0,10,30)
y=np.sin(x)

plt.plot(x,y,marker='o',color='black')
print('''

Marker discription
==================
=============   ===============================
character       description
=============   ===============================
``'.'``         point marker
``','``         pixel marker
``'o'``         circle marker
``'v'``         triangle_down marker
``'^'``         triangle_up marker
``'<'``         triangle_left marker
``'>'``         triangle_right marker
``'1'``         tri_down marker
``'2'``         tri_up marker
``'3'``         tri_left marker
``'4'``         tri_right marker
``'8'``         octagon marker
``'s'``         square marker
``'p'``         pentagon marker
``'P'``         plus (filled) marker
``'*'``         star marker
``'h'``         hexagon1 marker
``'H'``         hexagon2 marker
``'+'``         plus marker
``'x'``         x marker
``'X'``         x (filled) marker
``'D'``         diamond marker
``'d'``         thin_diamond marker
``'|'``         vline marker
``'_'``         hline marker
=============   ==============
''')
# Out:
# Marker discription
# ...
# =============   ===============================
# character       description
# =============   ===============================
# ``'.'``         point marker
# ``','``         pixel marker
# ``'o'``         circle marker
# ``'v'``         triangle_down marker
# ``'^'``         triangle_up marker
# ``'<'``         triangle_left marker
# ``'>'``         triangle_right marker
# ``'1'``         tri_down marker
# ``'2'``         tri_up marker
# ``'3'``         tri_left marker
# ``'4'``         tri_right marker
# ``'8'``         octagon marker
# ``'s'``         square marker
# ``'p'``         pentagon marker
# ``'P'``         plus (filled) marker
# ``'*'``         star marker
# ``'h'``         hexagon1 marker
# ``'H'``         hexagon2 marker
# ``'+'``         plus marker
# ``'x'``         x marker
# ``'X'``         x (filled) marker
# ``'D'``         diamond marker
# ``'d'``         thin_diamond marker
# ``'|'``         vline marker
# ``'_'``         hline marker
# ...

# %%
for marker in ['o','.',',','x','+','v','^','<','>','s','d']:
    plt.plot(np.random.rand(5), np.random.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x,y,'-o')

# %%
plt.plot(x,y,'-or')

# %%
# additional arguments in plt.plot
plt.plot(x,y,'-p',color='red',
        markersize=15,linewidth=5,
        markerfacecolor='yellow',
        markeredgecolor='Green',
        markeredgewidth=3)
plt.ylim(-1.2,1.2)
# Out:
# (-1.2, 1.2)

# %%
plt.scatter(x,y,marker='o')

# %%
x=np.random.randn(100)
y=np.random.randn(100)

colors=np.random.rand(100)
sizes=1000*np.random.rand(100)

plt.scatter(x,y,c=colors,s=sizes,alpha=0.3,cmap='viridis')

# %%
plt.scatter(x,y,c=colors,s=sizes,cmap='viridis')

# %%
plt.scatter(x,y,c=colors,s=sizes,alpha=0.4,cmap='viridis')

# %% [markdown]
# # Visualizing Error

# %% [markdown]
# # ============

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd

# %%
x=np.linspace(0,10,50)
dy=0.8
y=np.sin(x)+dy*np.random.randn(50)
plt.errorbar(x,y,yerr=dy,fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
x, y, yerr = np.random.randn(3, 10)
plt.errorbar(x, y, yerr, marker='s', mfc='red',
             mec='green', ms=20, mew=4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=0.3,fmt='o',color='black',
            ecolor='green',elinewidth=3,capsize=4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=2.0,fmt='o',color='black',
            ecolor='green',elinewidth=3,capsize=4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=0.3,fmt=':',color='black',
            ecolor='green',elinewidth=3,capsize=4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=1.0,fmt=' ',color='black',
            ecolor='green',elinewidth=3,capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=0.3,fmt='o',color='black',
            ecolor='green')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=0.8,fmt='-o',color='red',
            ecolor='green',elinewidth=4,capsize=5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(np.random.randn(30),np.random.randn(30),yerr=0.8,fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(np.random.randn(30),np.random.randn(30),yerr=0.8)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Density and Contour Plots
# # ======================

# %%
plt.style.use('seaborn-white')

# %%
# lets create a function
def f(x,y):
    return np.sin(x)**10+np.cos(10+y*x)*np.cos(x)

# %%
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)

X,Y=np.meshgrid(x,y)
z=f(X,Y)

# %%
z
# Out:
# array([[-0.83907153, -0.83470697, -0.8216586 , ...,  0.8956708 ,
#          0.68617261,  0.41940746],
#        [-0.83907153, -0.8275558 , -0.80744041, ...,  0.93467448,
#          0.77467433,  0.55894214],
#        [-0.83907153, -0.820263  , -0.79266951, ...,  0.98503397,
#          0.88847607,  0.73757604],
#        ...,
#        [-0.83907153, -0.48696962, -0.02692065, ...,  0.98525345,
#          0.79584263,  0.46799565],
#        [-0.83907153, -0.47558005, -0.00130271, ...,  0.93488414,
#          0.6993547 ,  0.37933079],
#        [-0.83907153, -0.46410908,  0.02431613, ...,  0.89579384,
#          0.65690314,  0.40107702]])

# %%
plt.contour(X,Y,z,colors='black')

# %%
plt.contour(X,colors='black')

# %%
plt.contour(Y,colors='black')

# %%
plt.contour(z,colors='black')

# %%
X
# Out:
# array([[0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#         5.        ],
#        [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#         5.        ],
#        [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#         5.        ],
#        ...,
#        [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#         5.        ],
#        [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#         5.        ],
#        [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#         5.        ]])

# %%
Y
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.12820513, 0.12820513, 0.12820513, ..., 0.12820513, 0.12820513,
#         0.12820513],
#        [0.25641026, 0.25641026, 0.25641026, ..., 0.25641026, 0.25641026,
#         0.25641026],
#        ...,
#        [4.74358974, 4.74358974, 4.74358974, ..., 4.74358974, 4.74358974,
#         4.74358974],
#        [4.87179487, 4.87179487, 4.87179487, ..., 4.87179487, 4.87179487,
#         4.87179487],
#        [5.        , 5.        , 5.        , ..., 5.        , 5.        ,
#         5.        ]])

# %%
plt.contour(X,Y,z,levels=50)

# %%
plt.contour(X,Y,z,levels=50,cmap='RdGy')

# %%
plt.contourf(X,Y,z,levels=20,cmap='RdGy')
plt.colorbar() # show you the color bar

# %%
plt.imshow(z,extent=[0,5,0,5],origin='lower',cmap='RdGy')
plt.colorbar()
# plt.axis(aspect='image')

# %%
contours=plt.contour(X,Y,z,3,colors='black')
plt.clabel(contours,inline=True,fontsize=8)

plt.imshow(z,extent=[0,5,0,5],origin='lower',cmap='RdGy',
           alpha=0.5)
plt.colorbar()
